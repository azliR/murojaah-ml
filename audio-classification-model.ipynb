# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import pandas as pd

from keras import layers
from keras import models
from IPython import display
# Out:
# 2023-06-21 14:54:12.187996: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 14:54:12.348398: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 14:54:12.350123: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 14:54:13.402782: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %run -i "./download_datasets_from_firestore.ipynb"
# Out:
# /home/azlir/.local/lib/python3.11/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
# %run -i "./download_audio_files.py"
# Out:
# Total data: 100
# Total labeled data: 96
# Audio Files: 100%|██████████| 96/96 [00:00<00:00, 15694.31it/s]
# File datasets%2F9d7b470e-8000-4f7a-9b4f-afb6407fdf93.wav already exists
# File datasets%2Fc691f744-c0ff-43b2-8a60-1b0f0dcfcab6.wav already exists
# File datasets%2F83a0cf5c-99fc-4085-9213-c24575e2a215.wav already exists
# File datasets%2Fb053b583-6d6e-4ab0-9ba9-33c9c7bf95a7.wav already exists
# File datasets%2Fdf781ad4-2529-4941-a6f2-ed030a1c5ed3.wav already exists
# File datasets%2Ffc830a5a-7a55-4027-8d5f-3eb32d374867.wav already exists
# File datasets%2F4c36ba2e-ca2f-4b85-a2cc-af73b3b61771.wav already exists
# File datasets%2F35b03ff4-d0d0-4d0e-ab76-18a6a983207c.wav already exists
# File datasets%2Fbfefcb9a-7d3c-44d6-831b-c9ab8cc789ca.wav already exists
# File datasets%2F5156793e-8a0c-4324-a302-a5a6361d89e8.wav already exists
# File datasets%2Ff64230c9-2451-426a-85f9-766d8ae16c83.wav already exists
# File datasets%2F747c1ba0-0a3f-4d7d-a753-5de8acc8c24a.wav already exists
# File datasets%2F36b6a7d0-b505-4202-a303-da33ba4fea74.wav already exists
# File datasets%2F57657596-aa23-4493-9a66-5f8ab985cf73.wav already exists
# File datasets%2F82ad5f8e-ad48-4193-99fa-69b7ebab4c89.wav already exists
# File datasets%2F9386b2d4-02eb-4b01-b4af-29908e63d452.wav already exists
# File datasets%2F58d7235f-47d6-465c-bcfc-2a63d8bcf973.wav already exists
# File datasets%2Fd2b71732-d0b7-4e16-8ac4-44eccb9cae17.wav already exists
# File datasets%2F54be224d-6950-4300-bdd6-92bce8e28713.wav already exists
# File datasets%2F30f495a5-8a25-4ce8-8441-664ebd1a1a09.wav already exists
# File datasets%2F9ba28027-9598-4c36-9e5f-f1463bbe9f07.wav already exists
# File datasets%2F97b269ad-ba2b-4ad7-bb46-67fea05640d0.wav already exists
# File datasets%2F134d4672-4073-43b0-898e-fd4eca95db4f.wav already exists
# File datasets%2F10992ba8-a640-4079-b6f7-9666f96c861a.wav already exists
# File datasets%2Ffd5b7516-b908-4f84-819e-9badc41481a6.wav already exists
# File datasets%2Fe45bec2c-0a93-474d-9e9a-5ee9b0d4960b.wav already exists
# File datasets%2Fe6a7b3a4-ff00-4296-9d07-b2de228e2824.wav already exists
# File datasets%2F12b6e408-876c-4c88-b8ae-dc8be8b85b2b.wav already exists
# File datasets%2F89567ccc-1f15-49e4-84b2-0fd654e35e3a.wav already exists
# File datasets%2Fa07ee7bc-4838-4c2e-ae2d-65becf06f26a.wav already exists
# File datasets%2F3f86e0ac-fe03-49f7-8b08-a2a78c012f1f.wav already exists
# File datasets%2Fffac767c-f883-456d-b92e-c5b069119071.wav already exists
# File datasets%2Fa666ade7-1363-4b7d-a5b5-68b2769b22ad.wav already exists
# File datasets%2Fcc75c76f-ebe4-4aee-8a7e-7e0611989228.wav already exists
# File datasets%2F9fbebe82-d0ae-4b89-8086-0aacc4dd6592.wav already exists
# File datasets%2F2172a68e-ddeb-4f9b-97d1-ad0901191ee7.wav already exists
# File datasets%2F8bbd7435-41d2-4cd6-8c52-92a57330869e.wav already exists
# File datasets%2Fc1fa81c8-b396-4969-8fb0-c5e081686087.wav already exists
# File datasets%2Fb76f2b7d-7318-4719-aa77-1f2a4c614465.wav already exists
# File datasets%2Fc280f902-ee26-485f-9d4e-dc8ae3e2a025.wav already exists
# File datasets%2Fa2a34827-2007-48d2-b495-026721cb364c.wav already exists
# File datasets%2F3dd785ba-50f3-45bc-99c5-9062e9e9e23a.wav already exists
# File datasets%2Feff21e46-842f-45e9-91d0-f44c901b2e45.wav already exists
# File datasets%2F8bffc772-6b8b-4900-b00f-d4f04e463dbd.wav already exists
# File datasets%2F1735e6bf-6f09-4caf-86de-4186e86a2e1b.wav already exists
# File datasets%2F9ad7b683-54b1-4e94-bf88-54402f450173.wav already exists
# File datasets%2Fd97a158c-c660-42b2-8cd8-2723f8f2e572.wav already exists
# File datasets%2F719a73d2-e96c-4b42-918f-e984d30e4911.wav already exists
# File datasets%2F479e9e05-3e54-453f-9ffa-63ff07768cb0.wav already exists
# File datasets%2F18ea0064-27c6-4463-a0a6-9dd0f3970dd2.wav already exists
# File datasets%2F0d3a51c0-c44b-409f-a00c-2aad6d6d6455.wav already exists
# File datasets%2F61142f4c-80c8-4410-ac6f-f4a026ce2170.wav already exists
# File datasets%2F1d1280f9-f12b-4fff-b0ab-73ed6c6ec222.wav already exists
# File datasets%2F5d5c81a6-02f4-41d2-a648-8a9f2c5bcb5f.wav already exists
# File datasets%2Fdbbf0507-d058-4979-99d8-3436752fc845.wav already exists
# File datasets%2Ffe5d0c33-f8ef-4c17-b60f-ceb5380dfebd.wav already exists
# File datasets%2F2e10f094-be89-4b8e-98d7-56bc27426ab9.wav already exists
# File datasets%2F0768f74b-5baa-4e9f-912e-3aa3b5d9defa.wav already exists
# File datasets%2F94f3797c-9d93-457e-aaef-f82a1a1b0d3f.wav already exists
# File datasets%2Fd3df6fb0-c5c3-4129-9133-aa38d4ebdd54.wav already exists
# File datasets%2F81afcd73-ac90-4b3d-9ae6-5becfe21e91b.wav already exists
# File datasets%2Fa35a2248-eb09-4254-b394-4e211faeb623.wav already exists
# File datasets%2F8a653ccc-ac87-4cef-92bf-1a8e2cfd7cb1.wav already exists
# File datasets%2F18943b87-4a33-4def-abd3-d4165a969acc.wav already exists
# File datasets%2Fc19fe4f1-6e6d-46a1-a1a7-641ce588fd68.wav already exists
# File datasets%2F754f33cb-f514-46a8-9ab3-e4e94cf1fc9b.wav already exists
# File datasets%2Fbfbc5915-e168-4a65-bad7-f4d9914a667f.wav already exists
# File datasets%2F41aafb24-6a90-413c-b084-6c15e4e7a052.wav already exists
# File datasets%2F2bc94f07-963f-482a-b0c1-470f31ef74c1.wav already exists
# File datasets%2Fe59ecda6-0096-4813-b7ad-480c5fb1e091.wav already exists
# File datasets%2F0f3359aa-e213-4538-9900-7b3fb7963579.wav already exists
# File datasets%2Fae09afc8-31e9-4940-92d9-69cc8a16f30d.wav already exists
# File datasets%2Fb91f83aa-b761-4e1d-9f95-55acee2d4904.wav already exists
# File datasets%2Fdee96403-105e-4dc1-9ba5-260d8d8752f1.wav already exists
# File datasets%2Ff499f062-81ad-4e46-b212-c3c1a0bdfef5.wav already exists
# File datasets%2F5081ea3b-792e-4520-8a93-2485fd369280.wav already exists
# File datasets%2Ff30c93bc-ecd1-481a-8ce2-aafa0b5e68f9.wav already exists
# File datasets%2Fe4aa03bb-8e31-4c63-a87c-951aab81211a.wav already exists
# File datasets%2F52b249c2-0786-4e09-9dc5-3d818b722c7f.wav already exists
# File datasets%2F031802bc-b4fb-4816-bcfb-c496d7116eb4.wav already exists
# File datasets%2F0f168e7c-3039-4c95-ac15-0d40c155cdd3.wav already exists
# File datasets%2Faf0825e9-0c15-490d-8b99-64a4b290a00a.wav already exists
# File datasets%2Ff5598791-b5ed-4ff4-ae7c-32f3a92a3e2c.wav already exists
# File datasets%2F946e71c5-aee0-4b39-84f8-9bfd96c2b5e3.wav already exists
# File datasets%2Ffd217b1d-c3de-401c-b647-ced14e20b277.wav already exists
# File datasets%2Fe7217e22-9166-42a3-961d-b4c4e2a2938b.wav already exists
# File datasets%2Fe788222e-fdc7-47bc-a015-ff1ffe95d516.wav already exists
# File datasets%2F2be730f1-fd64-40d8-9d3c-86c4073cfb40.wav already exists
# File datasets%2F0884a133-737d-467c-9059-5143f497d348.wav already exists
# File datasets%2Fd4c6f651-cc55-44b1-9f17-5d66a9391f86.wav already exists
# File datasets%2F67aca5d8-8f9a-46a6-9bc8-6c92a8d6ae9e.wav already exists
# File datasets%2Fb01357ba-5ac6-4305-9645-fde01a389bf7.wav already exists
# File datasets%2Ff5f9456d-7607-4dd2-9b13-a77b36ed3a67.wav already exists
# File datasets%2F01397803-01d7-40a3-9ddf-833249f6d786.wav already exists
# File datasets%2Fee816d54-eb9d-40e9-98c2-1bb717706e02.wav already exists
# File datasets%2Fa0e38a8b-af5a-48e2-9e44-5050cc38b6fe.wav already exists
# Succeed download: 96

# %%
# %run -i "./compress_audio_files.py"
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Fc691f744-c0ff-43b2-8a60-1b0f0dcfcab6.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Fc691f744-c0ff-43b2-8a60-1b0f0dcfcab6.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     169kB time=00:00:05.39 bitrate= 256.3kbits/s speed= 641x
# video:0kB audio:169kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.045139%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2F35b03ff4-d0d0-4d0e-ab76-18a6a983207c.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2F35b03ff4-d0d0-4d0e-ab76-18a6a983207c.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     128kB time=00:00:04.07 bitrate= 256.2kbits/s speed= 471x
# video:0kB audio:128kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059743%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Fd2b71732-d0b7-4e16-8ac4-44eccb9cae17.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Fd2b71732-d0b7-4e16-8ac4-44eccb9cae17.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     253kB time=00:00:08.09 bitrate= 256.1kbits/s speed= 610x
# video:0kB audio:253kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.030093%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2F54be224d-6950-4300-bdd6-92bce8e28713.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2F54be224d-6950-4300-bdd6-92bce8e28713.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     122kB time=00:00:03.89 bitrate= 256.2kbits/s speed= 575x
# video:0kB audio:122kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.062500%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Fd97a158c-c660-42b2-8cd8-2723f8f2e572.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Fd97a158c-c660-42b2-8cd8-2723f8f2e572.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     278kB time=00:00:08.87 bitrate= 256.1kbits/s speed= 680x
# video:0kB audio:278kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027449%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2F61142f4c-80c8-4410-ac6f-f4a026ce2170.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2F61142f4c-80c8-4410-ac6f-f4a026ce2170.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     158kB time=00:00:05.04 bitrate= 255.9kbits/s speed= 473x
# video:0kB audio:158kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048363%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2F754f33cb-f514-46a8-9ab3-e4e94cf1fc9b.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2F754f33cb-f514-46a8-9ab3-e4e94cf1fc9b.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     154kB time=00:00:04.91 bitrate= 256.2kbits/s speed= 394x
# video:0kB audio:154kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.049543%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Fae09afc8-31e9-4940-92d9-69cc8a16f30d.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Fae09afc8-31e9-4940-92d9-69cc8a16f30d.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     158kB time=00:00:05.03 bitrate= 256.2kbits/s speed= 609x
# video:0kB audio:158kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048363%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Fb76f2b7d-7318-4719-aa77-1f2a4c614465.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Fb76f2b7d-7318-4719-aa77-1f2a4c614465.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     156kB time=00:00:05.01 bitrate= 254.1kbits/s speed= 546x
# video:0kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048946%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2F0f3359aa-e213-4538-9900-7b3fb7963579.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2F0f3359aa-e213-4538-9900-7b3fb7963579.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     255kB time=00:00:08.15 bitrate= 256.1kbits/s speed= 519x
# video:0kB audio:255kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.029871%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Ff499f062-81ad-4e46-b212-c3c1a0bdfef5.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Ff499f062-81ad-4e46-b212-c3c1a0bdfef5.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     128kB time=00:00:04.07 bitrate= 256.2kbits/s speed= 625x
# video:0kB audio:128kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059743%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Ffd217b1d-c3de-401c-b647-ced14e20b277.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Ffd217b1d-c3de-401c-b647-ced14e20b277.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     109kB time=00:00:03.47 bitrate= 256.3kbits/s speed= 626x
# video:0kB audio:109kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.070043%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_6/datasets%2Fd4c6f651-cc55-44b1-9f17-5d66a9391f86.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_6/datasets%2Fd4c6f651-cc55-44b1-9f17-5d66a9391f86.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     156kB time=00:00:04.97 bitrate= 256.2kbits/s speed= 677x
# video:0kB audio:156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048946%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
# ...
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_4/datasets%2F9d7b470e-8000-4f7a-9b4f-afb6407fdf93.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_4/datasets%2F9d7b470e-8000-4f7a-9b4f-afb6407fdf93.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     174kB time=00:00:05.57 bitrate= 256.1kbits/s speed= 510x
# video:0kB audio:174kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.043683%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_4/datasets%2Fa07ee7bc-4838-4c2e-ae2d-65becf06f26a.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_4/datasets%2Fa07ee7bc-4838-4c2e-ae2d-65becf06f26a.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=      69kB time=00:00:02.20 bitrate= 258.4kbits/s speed= 549x
# video:0kB audio:69kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.109797%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_4/datasets%2Fdbbf0507-d058-4979-99d8-3436752fc845.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_4/datasets%2Fdbbf0507-d058-4979-99d8-3436752fc845.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     141kB time=00:00:04.49 bitrate= 256.2kbits/s speed= 613x
# video:0kB audio:141kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.054167%
# Conversion completed!
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_4/datasets%2Fc19fe4f1-6e6d-46a1-a1a7-641ce588fd68.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_4/datasets%2Fc19fe4f1-6e6d-46a1-a1a7-641ce588fd68.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     143kB time=00:00:04.55 bitrate= 256.2kbits/s speed= 610x
# video:0kB audio:142kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.053454%
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-U_FORTIFY_SOURCE,-D_FORTIFY_SOURCE=3 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fno-omit-frame-pointer -mno-omit-leaf-frame-pointer' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -Wl,--build-id=sha1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --enable-chromaprint --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libbs2b --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libilbc --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenh264 --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-libplacebo --enable-librsvg --enable-librav1e --enable-librubberband --enable-libsmbclient --enable-version3 --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libvpl --enable-runtime-cpudetect
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, matroska,webm, from './audio/surah_1/ayah_4/datasets%2F0f168e7c-3039-4c95-ac15-0d40c155cdd3.wav':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './audio_16k/surah_1/ayah_4/datasets%2F0f168e7c-3039-4c95-ac15-0d40c155cdd3.wav':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     116kB time=00:00:03.73 bitrate= 254.9kbits/s speed= 583x
# video:0kB audio:116kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.065524%

# %%
# %run -i "./augment_audio_files.py"
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]/home/azlir/.local/lib/python3.11/site-packages/audiomentations/core/transforms_interface.py:57: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# /home/azlir/.local/lib/python3.11/site-packages/audiomentations/core/transforms_interface.py:57: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# /home/azlir/.local/lib/python3.11/site-packages/audiomentations/core/transforms_interface.py:57: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# 100%|██████████| 13/13 [00:03<00:00,  3.87it/s]
# 100%|██████████| 13/13 [00:03<00:00,  4.07it/s]
# 100%|██████████| 13/13 [00:06<00:00,  2.03it/s]
# 100%|██████████| 14/14 [00:03<00:00,  4.31it/s]
# 100%|██████████| 16/16 [00:03<00:00,  4.48it/s]
# 100%|██████████| 14/14 [00:02<00:00,  5.65it/s]
# 100%|██████████| 13/13 [00:02<00:00,  6.28it/s]
# Conversion completed!

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
audio_dir = './audio_augmented/surah_1'

# %%
train_ds, test_val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=audio_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both')

label_names = np.array(train_ds.class_names)
print()
print("label names:", label_names)
# Out:
# Found 576 files belonging to 7 classes.
# Using 461 files for training.
# Using 115 files for validation.
#
# label names: ['ayah_1' 'ayah_2' 'ayah_3' 'ayah_4' 'ayah_5' 'ayah_6' 'ayah_7']

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels


train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
test_val_ds = test_val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
test_ds = test_val_ds.shard(num_shards=2, index=0)
val_ds = test_val_ds.shard(num_shards=2, index=1)

# %%
for example_audio, example_labels in test_ds.take(1):
    print(example_audio.shape)
    print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)
# 2023-06-21 14:59:46.918685: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [115]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-21 14:59:46.919107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [115]
# 	 [[{{node Placeholder/_4}}]]

# %%
label_names[[0, 1, 2, 3, 4, 5, 6]]
# Out:
# array(['ayah_1', 'ayah_2', 'ayah_3', 'ayah_4', 'ayah_5', 'ayah_6',
#        'ayah_7'], dtype='<U6')

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))
for i in range(n):
    if i >= n:
        break
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    ax.plot(example_audio[i].numpy())
    ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
    label = label_names[example_labels[i]]
    ax.set_title(label)
    ax.set_ylim([-1.1, 1.1])

plt.show()

# %%
def get_spectrogram(waveform):
    # Convert the waveform to a spectrogram via a STFT.
    spectrogram = tf.signal.stft(
        waveform, frame_length=255, frame_step=128)
    # Obtain the magnitude of the STFT.
    spectrogram = tf.abs(spectrogram)
    # Add a `channels` dimension, so that the spectrogram can be used
    # as image-like input data with convolution layers (which expect
    # shape (`batch_size`, `height`, `width`, `channels`).
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram

# %%
for i in range(3):
    label = label_names[example_labels[i]]
    waveform = example_audio[i]
    spectrogram = get_spectrogram(waveform)

    print('Label:', label)
    print('Waveform shape:', waveform.shape)
    print('Spectrogram shape:', spectrogram.shape)
    print('Audio playback')
    display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: ayah_3
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ayah_1
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: ayah_5
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
    if len(spectrogram.shape) > 2:
        assert len(spectrogram.shape) == 3
        spectrogram = np.squeeze(spectrogram, axis=-1)
    # Convert the frequencies to log scale and transpose, so that the time is
    # represented on the x-axis (columns).
    # Add an epsilon to avoid taking a log of zero.
    log_spec = np.log(spectrogram.T + np.finfo(float).eps)
    height = log_spec.shape[0]
    width = log_spec.shape[1]
    X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
    Y = range(height)
    ax.pcolormesh(X, Y, log_spec)

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %%
def make_spec_ds(ds):
    return ds.map(
        map_func=lambda audio, label: (get_spectrogram(audio), label),
        num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
    break
# Out:
# 2023-06-21 15:00:07.646006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [461]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-21 15:00:07.646554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [461]
# 	 [[{{node Placeholder/_0}}]]

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)

norm_layer = layers.Normalization()

norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    # Normalize.
    norm_layer,
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(num_labels, activation='relu'),
])

model.summary()
# Out:
# Input shape: (124, 129, 1)
# 2023-06-21 15:12:53.811204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [461]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-21 15:12:53.811699: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [461]
# 	 [[{{node Placeholder/_0}}]]
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_5 (Normalizat  (None, 124, 129, 1)      3
#  ion)
#
#  conv2d_10 (Conv2D)          (None, 122, 127, 32)      320
#
#  max_pooling2d_10 (MaxPoolin  (None, 61, 63, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 59, 61, 32)        9248
#
#  max_pooling2d_11 (MaxPoolin  (None, 29, 30, 32)       0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 29, 30, 32)        0
#
#  flatten_7 (Flatten)         (None, 27840)             0
#
#  dense_15 (Dense)            (None, 128)               3563648
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 3,581,930
# Trainable params: 3,581,927
# Non-trainable params: 3
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 20
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=10),
)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 4s 375ms/step - loss: 1.9299 - accuracy: 0.1692 - val_loss: 1.9128 - val_accuracy: 0.1765
# Epoch 2/20
# 8/8 [==============================] - 3s 358ms/step - loss: 1.8530 - accuracy: 0.2538 - val_loss: 1.9110 - val_accuracy: 0.4118
# Epoch 3/20
# 8/8 [==============================] - 3s 353ms/step - loss: 1.8226 - accuracy: 0.2690 - val_loss: 1.8183 - val_accuracy: 0.3922
# Epoch 4/20
# 8/8 [==============================] - 3s 351ms/step - loss: 1.7458 - accuracy: 0.3059 - val_loss: 1.7205 - val_accuracy: 0.3922
# Epoch 5/20
# 8/8 [==============================] - 3s 372ms/step - loss: 1.6669 - accuracy: 0.3557 - val_loss: 1.6775 - val_accuracy: 0.4510
# Epoch 6/20
# 8/8 [==============================] - 3s 345ms/step - loss: 1.5967 - accuracy: 0.4208 - val_loss: 1.5688 - val_accuracy: 0.4706
# Epoch 7/20
# 8/8 [==============================] - 3s 355ms/step - loss: 1.5036 - accuracy: 0.4577 - val_loss: 1.4873 - val_accuracy: 0.5098
# Epoch 8/20
# 8/8 [==============================] - 3s 358ms/step - loss: 1.3761 - accuracy: 0.5098 - val_loss: 1.4652 - val_accuracy: 0.5098
# Epoch 9/20
# 8/8 [==============================] - 3s 351ms/step - loss: 1.3033 - accuracy: 0.5380 - val_loss: 1.5017 - val_accuracy: 0.5098
# Epoch 10/20
# 8/8 [==============================] - 3s 360ms/step - loss: 1.2590 - accuracy: 0.5423 - val_loss: 1.5067 - val_accuracy: 0.5490
# Epoch 11/20
# 8/8 [==============================] - 3s 358ms/step - loss: 1.1573 - accuracy: 0.6052 - val_loss: 1.4542 - val_accuracy: 0.5294
# Epoch 12/20
# 8/8 [==============================] - 3s 360ms/step - loss: 1.1139 - accuracy: 0.6161 - val_loss: 1.3516 - val_accuracy: 0.5686
# Epoch 13/20
# 8/8 [==============================] - 3s 359ms/step - loss: 0.9807 - accuracy: 0.6443 - val_loss: 1.2727 - val_accuracy: 0.6078
# Epoch 14/20
# 8/8 [==============================] - 3s 353ms/step - loss: 0.8968 - accuracy: 0.6833 - val_loss: 1.2544 - val_accuracy: 0.6863
# Epoch 15/20
# 8/8 [==============================] - 3s 358ms/step - loss: 0.8482 - accuracy: 0.6985 - val_loss: 1.2302 - val_accuracy: 0.7059
# Epoch 16/20
# 8/8 [==============================] - 3s 379ms/step - loss: 0.8233 - accuracy: 0.7050 - val_loss: 1.2168 - val_accuracy: 0.7059
# Epoch 17/20
# 8/8 [==============================] - 3s 354ms/step - loss: 0.7488 - accuracy: 0.7310 - val_loss: 1.0525 - val_accuracy: 0.7059
# Epoch 18/20
# 8/8 [==============================] - 3s 358ms/step - loss: 0.7235 - accuracy: 0.7570 - val_loss: 0.8954 - val_accuracy: 0.7647
# Epoch 19/20
# 8/8 [==============================] - 3s 364ms/step - loss: 0.7345 - accuracy: 0.7527 - val_loss: 0.8827 - val_accuracy: 0.8039
# Epoch 20/20
# 8/8 [==============================] - 3s 364ms/step - loss: 0.6206 - accuracy: 0.7983 - val_loss: 0.7809 - val_accuracy: 0.8431

# %%
metrics = history.history
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1, 2, 2)
plt.plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 1/1 [==============================] - 0s 229ms/step - loss: 1.0710 - accuracy: 0.7656
# {'loss': 1.070976734161377, 'accuracy': 0.765625}

# %%
y_pred = model.predict(test_spectrogram_ds)
# Out:
# 1/1 [==============================] - 0s 226ms/step

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s, lab: lab)), axis=0)
# Out:
# 2023-06-21 13:47:09.908889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [115]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-21 13:47:09.909291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [115]
# 	 [[{{node Placeholder/_4}}]]

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
x = os.path.join(audio_dir, 'ayah_1/datasets%2F36b6a7d0-b505-4202-a303-da33ba4fea74.wav')
x = tf.io.read_file(str(x))
x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000, )
x = tf.squeeze(x, axis=-1)
waveform = x
x = get_spectrogram(x)
x = x[tf.newaxis, ...]

prediction = model(x)
x_labels = label_names
plt.bar(x_labels, tf.nn.softmax(prediction[0]))
plt.title('ayah_1')
plt.show()

display.display(display.Audio(waveform, rate=16000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
